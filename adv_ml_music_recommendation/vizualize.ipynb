# %%
import pandas as pd
df_playlist = pd.read_csv("../data/track_playlist_association.csv")
df_tracks = pd.read_csv("../data/matched_songs.csv")

# %%
import numpy as np
from scipy.sparse.linalg import svds

# Define the original matrix R
R = np.array([[1, 0, 1, 0],
              [0, 1, 0, 1],
              [1, 1, 0, 0]], dtype=np.float32)

# Perform Singular Value Decomposition (SVD)
# We decompose R into U, Sigma, V^T
U, Sigma, Vt = svds(R, k=2)  # k=2 for the top 2 singular values

# Reconstruct the predicted ratings matrix (hat{R}) from U, Sigma, V^T
Sigma = np.diag(Sigma)  # Convert Sigma to a diagonal matrix
hat_R = np.dot(np.dot(U, Sigma), Vt)

# Print the predicted matrix
print("Predicted ratings matrix (hat{R}):")
print(hat_R)
# Out:
# Predicted ratings matrix (hat{R}):
# [[ 1.1035534   0.1035533   0.75       -0.25000006]
#  [ 0.10355345  1.1035533  -0.25000006  0.7499999 ]
#  [ 0.85355365  0.8535536   0.35355335  0.35355344]]

# %%
# Results from min_tracks=50
# Data for hyperparameters and corresponding average accuracy
hyperparams_data = [{"vector_size": 50, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.007649794645609453},
    {"vector_size": 50, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.03706732020291377},
    {"vector_size": 50, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.016000170135926264},
    {"vector_size": 50, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.05645575230527246},
    {"vector_size": 50, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.020886645680131204},
    {"vector_size": 50, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.06507763370520578},
    {"vector_size": 50, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.009787186693395395},
    {"vector_size": 50, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.052769313282333905},
    {"vector_size": 50, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.019425577949490125},
    {"vector_size": 50, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.07073026418309572},
    {"vector_size": 50, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.023395007939899674},
    {"vector_size": 50, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.07878377094669756},
    {"vector_size": 50, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.011880860039153635},
    {"vector_size": 50, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.05484108312122901},
    {"vector_size": 50, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.02631465371953483},
    {"vector_size": 50, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.07532290863940444},
    {"vector_size": 50, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.03053203848516583},
    {"vector_size": 50, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.07939647833736885},
    {"vector_size": 100, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.008024666100746628},
    {"vector_size": 100, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.04226056013411976},
    {"vector_size": 100, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.0194523311696881},
    {"vector_size": 100, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.06468043120087377},
    {"vector_size": 100, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.02629555021598486},
    {"vector_size": 100, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.07446237009019943},
    {"vector_size": 100, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.010443929049058049},
    {"vector_size": 100, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.054674710979199265},
    {"vector_size": 100, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.02609315502133669},
    {"vector_size": 100, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.07919610856783463},
    {"vector_size": 100, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.02870367108469026},
    {"vector_size": 100, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.08716454786052598},
    {"vector_size": 100, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.012473518646524795},
    {"vector_size": 100, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.05989227209600251},
    {"vector_size": 100, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.031194351072132274},
    {"vector_size": 100, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.08102356394994988},
    {"vector_size": 100, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.03522904734542648},
    {"vector_size": 100, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.08940235493424882},
    {"vector_size": 200, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.00825619513897867},
    {"vector_size": 200, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.03876545960559423},
    {"vector_size": 200, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.019528412795433138},
    {"vector_size": 200, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.06039090722588822},
    {"vector_size": 200, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.02606055210932085},
    {"vector_size": 200, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.06856858998942475},
    {"vector_size": 200, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.01034092915479743},
    {"vector_size": 200, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.04988355361506397},
    {"vector_size": 200, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.0253583057898499},
    {"vector_size": 200, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.06893170543672224},
    {"vector_size": 200, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.028504752680390363},
    {"vector_size": 200, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.0775508380994329},
    {"vector_size": 200, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.012074748003342732},
    {"vector_size": 200, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.054040188890763535},
    {"vector_size": 200, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.030730048042175342},
    {"vector_size": 200, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.07063028188691281},
    {"vector_size": 200, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.0341836183165348},
    {"vector_size": 200, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.08099967810917319}
]

# %%
data = [
    {"vector_size": 50, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.027005281003112724},
    {"vector_size": 50, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.12616817233188943},
    {"vector_size": 50, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.055908313053162365},
    {"vector_size": 50, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.17365131457646024},
    {"vector_size": 50, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.06263633780896112},
    {"vector_size": 50, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.18948748189475045},
    {"vector_size": 50, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.033446851465738045},
    {"vector_size": 50, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.15806747740925528},
    {"vector_size": 50, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.06270757726162879},
    {"vector_size": 50, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.19706282438807876},
    {"vector_size": 50, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.06695365818881158},
    {"vector_size": 50, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.21811845234933525},
    {"vector_size": 50, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.03593317831378279},
    {"vector_size": 50, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.1705338725052582},
    {"vector_size": 50, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.06993601708285035},
    {"vector_size": 50, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.21183891765333662},
    {"vector_size": 50, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.07772616681051231},
    {"vector_size": 50, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.22113756165397172},
    {"vector_size": 100, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.028119125082732552},
    {"vector_size": 100, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.12569435896067696},
    {"vector_size": 100, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.058634812855855575},
    {"vector_size": 100, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.18282978137686995},
    {"vector_size": 100, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.06739727551640629},
    {"vector_size": 100, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.2022149804361095},
    {"vector_size": 100, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.03443164581983169},
    {"vector_size": 100, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.16101046532110178},
    {"vector_size": 100, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.06624119896929515},
    {"vector_size": 100, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.21833936264048254},
    {"vector_size": 100, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.0717673198786932},
    {"vector_size": 100, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.23198156086614435},
    {"vector_size": 100, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.039301323675871414},
    {"vector_size": 100, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.1741631150059105},
    {"vector_size": 100, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.07556326320257532},
    {"vector_size": 100, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.22059940776395434},
    {"vector_size": 100, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.08271415324336652},
    {"vector_size": 100, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.24214907005465192},
    {"vector_size": 200, "window": 5, "epochs": 10, "sg": 0, "accuracy": 0.026723269411830182},
    {"vector_size": 200, "window": 5, "epochs": 10, "sg": 1, "accuracy": 0.11421276354463},
    {"vector_size": 200, "window": 5, "epochs": 20, "sg": 0, "accuracy": 0.05617437811392638},
    {"vector_size": 200, "window": 5, "epochs": 20, "sg": 1, "accuracy": 0.1566032890123303},
    {"vector_size": 200, "window": 5, "epochs": 30, "sg": 0, "accuracy": 0.06415586516945368},
    {"vector_size": 200, "window": 5, "epochs": 30, "sg": 1, "accuracy": 0.1694631553232347},
    {"vector_size": 200, "window": 10, "epochs": 10, "sg": 0, "accuracy": 0.035194533766464295},
    {"vector_size": 200, "window": 10, "epochs": 10, "sg": 1, "accuracy": 0.1432776819042285},
    {"vector_size": 200, "window": 10, "epochs": 20, "sg": 0, "accuracy": 0.06609737010220035},
    {"vector_size": 200, "window": 10, "epochs": 20, "sg": 1, "accuracy": 0.17947960559763454},
    {"vector_size": 200, "window": 10, "epochs": 30, "sg": 0, "accuracy": 0.07133785389849265},
    {"vector_size": 200, "window": 10, "epochs": 30, "sg": 1, "accuracy": 0.20067968961712176},
    {"vector_size": 200, "window": 15, "epochs": 10, "sg": 0, "accuracy": 0.03790150948877062},
    {"vector_size": 200, "window": 15, "epochs": 10, "sg": 1, "accuracy": 0.14908600569348815},
    {"vector_size": 200, "window": 15, "epochs": 20, "sg": 0, "accuracy": 0.07377290453010892},
    {"vector_size": 200, "window": 15, "epochs": 20, "sg": 1, "accuracy": 0.18636275866358282},
    {"vector_size": 200, "window": 15, "epochs": 30, "sg": 0, "accuracy": 0.08081493740280712},
    {"vector_size": 200, "window": 15, "epochs": 30, "sg": 1, "accuracy": 0.20842610032168762},
]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_accuracy_by_params(data):
    # Convert input data to DataFrame
    df = pd.DataFrame(data, columns=["vector_size", "window", "epochs", "sg", "accuracy"])

    # Create subplots for each vector_size and training algorithm
    g = sns.relplot(
        data=df,
        x="epochs", y="accuracy",
        hue="window", style="sg",
        col="vector_size", row="sg",
        kind="line", markers=True, dashes=False,
        row_order=[1, 0],  # Ensures Skip-Gram (1) is on top
        facet_kws={"sharey": True, "margin_titles": True},
        height=3, aspect=1.2,  # Decrease height and width for smaller plots
        palette="viridis"  # Color-blind friendly
    )

    # Customize titles and labels
    g.set_titles("Vector Size: {col_name} | Algorithm: {'Skip-Gram' if row_name else 'CBOW'}")
    g.set_axis_labels("Epochs", "Accuracy")
    g.tight_layout()

    # Annotate maximum accuracy in each subplot
    for ax in g.axes.flat:
        if not ax.lines: continue
        max_acc = max([line.get_ydata()[-1] for line in ax.lines if len(line.get_ydata()) > 0])  # Get final epoch accuracy
        ax.annotate(
            f"Max: {max_acc:.3f}", 
            xy=(30, max_acc), 
            xytext=(-50, 10), textcoords="offset points",
            arrowprops=dict(arrowstyle="->", color="red"),
            color="red", fontweight="bold"
        )

    output_path = "accuracy_plot.svg"  # Change the filename as needed
    g.figure.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()
    
plot_accuracy_by_params(data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_hyperparameter_tuning(k_values, accuracies, output_path="k.svg"):
    # Set theme to match previous relplot style
    sns.set_theme(style="darkgrid")

    # Create plot
    fig, ax = plt.subplots(figsize=(5, 3))  # Same scale as your relplot

    # Use a color from Seaborn's "viridis" palette (ensuring it matches previous plots)
    color = sns.color_palette("viridis", 4)[-2]

    # Line plot with markers
    ax.plot(k_values, accuracies, marker="o", linestyle="-", color=color, markersize=5, label="Accuracy")

    # Labels and title
    ax.set_xlabel("Number of Latent Factors (k)")
    ax.set_ylabel("Accuracy")
    ax.set_title("Hyperparameter Tuning for k in Collaborative Filtering", fontsize=10)

    # Customize grid (same as relplot)
    ax.grid(True, linestyle="--", alpha=0.6)

    # Ensure consistent tick label formatting
    ax.set_xticks(k_values)

    # Legend styling to match relplot
    ax.legend(frameon=False)

    # Save figure in high quality
    plt.savefig(output_path, dpi=300, bbox_inches="tight")

    # Show plot
    plt.show()

# Example usage
# min_tracks=100
# min_tracks=100
k_values_100 = [5, 20, 50, 100]
accuracies_100 = [0.1873, 0.2903, 0.2861, 0.1895]

# min_tracks=50
k_values_50 = [5, 20, 50, 100]
accuracies_50 = [0.15999199418017687, 0.21511735354003142, 0.23170978159033123, 0.23891736079136294]

# min_tracks=50
plot_hyperparameter_tuning(k_values_50, accuracies_50)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_hyperparameter_tuning_alpha(alpha_values, accuracies, output_path="alpha.svg"):
    # Set style to match previous plots
    sns.set_theme(style="darkgrid")

    # Create plot
    fig, ax = plt.subplots(figsize=(5, 3))  # Matches previous plots

    # Use a color from Seaborn's "viridis" palette
    color = sns.color_palette("viridis", 4)[-2]

    # Line plot with markers
    ax.plot(alpha_values, accuracies, marker="o", linestyle="-", color=color, markersize=5, label="Accuracy")

    # Labels and title
    ax.set_xlabel("Content Weight (α)")
    ax.set_ylabel("Accuracy")
    ax.set_title("Hyperparameter Tuning for α in Hybrid Recommender", fontsize=10)

    # Consistent grid styling
    ax.grid(True, linestyle="--", alpha=0.6)

    # Set x-axis ticks explicitly
    ax.set_xticks(alpha_values)

    # Legend styling
    ax.legend(frameon=False)

    # Save figure in high quality
    plt.savefig(output_path, dpi=300, bbox_inches="tight")

    # Show plot
    plt.show()

# Example usage
alpha_values = [0.2, 0.5, 0.8]
accuracies = [0.35098, 0.36869, 0.37343]

alpha_values_50 = [0.2, 0.5, 0.8]
accuracies_50 = [0.26438035428193873, 0.2724520850616268, 0.20834825654771788]
plot_hyperparameter_tuning_alpha(alpha_values, accuracies)

# %%
from adv_ml_music_recommendation.recommenders.hybridrecommender import HybridRecommender

recommender = HybridRecommender(df_playlist=df_playlist, df_tracks=df_tracks)

# Get the top 10 recommended tracks for a specific playlist
playlist_id = 10 # Replace with the playlist_id for which you want recommendations
top_k = 10  # Number of tracks to recommend

playlist_embedding = recommender.content_recommender.construct_playlist_embedding(playlist_id)
recommender.content_recommender.visualize_embedding(playlist_embedding)
# Out:
# Loss 65741348.0
#
# === Top 10 Closest Tracks ===
#
# #1: help (feat. Maejor)
#   Artists: blackbear, Maejor
#   Album: Help
#   Track URI: spotify:track:0IHjY58S1OdnealEbadJQ1
#
# #2: 4u
#   Artists: blackbear
#   Album: Deadroses
#   Track URI: spotify:track:1XcXhu1X0xBFMDFyq0b7Ue
#
# #3: dirty laundry
#   Artists: blackbear
#   Album: Deadroses
#   Track URI: spotify:track:0qgZvYWLIqDn0tXimF8gPa
#
# #4: paragraphs
#   Artists: blackbear
#   Album: Help
#   Track URI: spotify:track:49GFP1sA528wDMaDdQgwLo
#
# #5: nervous
#   Artists: blackbear
#   Album: Help
#   Track URI: spotify:track:0FkKoIRproCB2faGlpPtry
#
# #6: oh lord
#   Artists: blackbear
#   Album: Help
#   Track URI: spotify:track:1i6eoKAP8V6kVeW5FHxW8q
#
# #7: different hos
#   Artists: blackbear
#   Album: Help
#   Track URI: spotify:track:2Y4DwuII6ZzFZxmvD1s5o5
#
# #8: The Hottest
#   Artists: CJ Hilton
#   Album: This Is Me
#   Track URI: spotify:track:0OVL1U62nFQy62uTGUJdjv
#
# #9: Stampede
#   Artists: YEAR OF THE OX
#   Album: YOX EP
#   Track URI: spotify:track:1WQJqbtfyvDaR4ktWKYVKP
#
# #10: Pathetic
#   Artists: Erik Hassle
#   Album: Innocence Lost
#   Track URI: spotify:track:3kC6803yj2CXjYsNDUkpLM

# %%
playlist_embedding = recommender.content_recommender.construct_playlist_embedding(30)
recommender.content_recommender.visualize_embedding(playlist_embedding, top_n=50)
# Out:
# === Top 50 Closest Tracks ===
#
# #1: Fire's Highway
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:7pjyI9ulr1P3xR2JtFp3IG
#
# #2: Adrenaline Nightshift
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:0sq6L0pQRdMCnQ5N76U4AJ
#
# #3: Evil's Sway
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:0cMeyVzzSstLgkxMBcu2G5
#
# #4: Younger Us
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:5lLyaFsXQ2GASksFhGA9It
#
# #5: For the Love of Ivy
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:7oAtwYnc4LQqjZYcCC5Yub
#
# #6: Heaven
#   Artists: Pomegranates
#   Album: Heaven
#   Track URI: spotify:track:0pTvxZM3ffLXvLT8mBZgaR
#
# #7: Ezekiel
#   Artists: Pomegranates
#   Album: Heaven
#   Track URI: spotify:track:1SNJoL6GiMPlDfHjJTRTN2
#
# #8: The House That Heaven Built
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:2dcmQJCw1INGn7yR2KHx0U
#
# #9: Continuous Thunder
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:1WTMcJpdYwVeXOaqG3X68E
#
# #10: The Nights of Wine and Roses
#   Artists: Japandroids
#   Album: Celebration Rock
#   Track URI: spotify:track:1lsxBwhhgm0xUYCQwISwdB
#
# #11: Hayride
#   Artists: Brian Bromberg
#   Album: Compared to That
#   Track URI: spotify:track:2BHwpqOON9A0eUc3Rtstwr
#
# #12: Sisters
#   Artists: Pomegranates
#   Album: Heaven
#   Track URI: spotify:track:526wdpGnlMkaVSQF1limK2
#
# #13: Go All The Way
#   Artists: Luis Cardenas
#   Album: Animal Instinct: Collectors Edition
#   Track URI: spotify:track:3FD46IxEFjdhLdbcvCmpBs
#
# #14: Death On Two Legs
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:4FYty8yf9cznpbbz4UYzFM
#
# #15: Compared To That
#   Artists: Brian Bromberg
#   Album: Compared to That
#   Track URI: spotify:track:1ksMZsSdHwiRewVaFYuN8e
#
# #16: Tighten Up
#   Artists: Jack and White, Brooke White
#   Album: Undercover
#   Track URI: spotify:track:5KbgZZTDv2poiAr0DavMwm
#
# #17: Sketch
#   Artists: The Inner Banks
#   Album: WILD
#   Track URI: spotify:track:5uSlUEPBcjL1maYAZrvm5k
#
# #18: I'm Just Sayin'
#   Artists: Brian Bromberg
#   Album: Compared to That
#   Track URI: spotify:track:3fVTMM0EYPWbwY0vN0QZKM
#
# #19: Box and Crown
#   Artists: The Inner Banks
#   Album: WILD
#   Track URI: spotify:track:5u74KwvH0wcA8xFkTwaLw9
#
# #20: Jack The Ripper
#   Artists: Japandroids
#   Album: The House That Heaven Built
#   Track URI: spotify:track:5ZhEotwTNj45EeUfPhgYqp
#
# #21: Lost Lives
#   Artists: Pomegranates
#   Album: Heaven
#   Track URI: spotify:track:0XLZppP3bCM3X35scXx4n5
#
# #22: Piano (Interlude)
#   Artists: Oh No
#   Album: Ohnomite
#   Track URI: spotify:track:7a4apvkoaXzvE9iPT7RM55
#
# #23: Flash
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:0hjxP3RjJ3yeOvHm73hisG
#
# #24: The Blessing
#   Artists: Ben Tankard
#   Album: Full Tank
#   Track URI: spotify:track:4ARXqyTyX0OeVGTS3Tl8yd
#
# #25: Ohnomite Jazz
#   Artists: Oh No
#   Album: Ohnomite
#   Track URI: spotify:track:2itbslPLw52KnbiczzG6gw
#
# #26: Under Pressure
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:0IokXyjcpPPfHON5Sm1mkT
#
# #27: Killer Queen
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:1J3TYrtGAc7KE0YPwYjSaP
#
# #28: The Eclipse
#   Artists: Brian Bromberg
#   Album: Compared to That
#   Track URI: spotify:track:1U6FYL2QiUhP1Ax6ktTseN
#
# #29: Bohemian Rhapsody
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:2ASfiR7nlSuUEXTuvc7Lw6
#
# #30: The Crowing
#   Artists: Coheed and Cambria
#   Album: In Keeping Secrets Of Silent Earth: 3
#   Track URI: spotify:track:7fT97iUO2mul3BIAAut70b
#
# #31: Let's Roll (feat. Damani)
#   Artists: Oh No, Damani
#   Album: Ohnomite
#   Track URI: spotify:track:7nhR4BntChCB1Y2EuSetX3
#
# #32: Pass Away
#   Artists: Pomegranates
#   Album: Heaven
#   Track URI: spotify:track:4OHY67HObOgGR4XckkUIpB
#
# #33: Somebody to Love
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:6jtAs2qWwEYgFJk4cj6YoD
#
# #34: The Show Must Go On
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:1tiqCN4Fl6yvrv1sZJ7F5O
#
# #35: Shaved For Battle
#   Artists: Stars and Stripes
#   Album: Shaved For Battle
#   Track URI: spotify:track:5YH0Msv0YDvNZLoqQr3s8E
#
# #36: California Dreamin'
#   Artists: Jack and White, Brooke White
#   Album: Undercover
#   Track URI: spotify:track:6vrMPmHqgB6qcnJiLSLn9l
#
# #37: The Lovers' suicide
#   Artists: The Bilinda Butchers
#   Album: Heaven
#   Track URI: spotify:track:13SFLoxIV5AHD9R2Zs9RRj
#
# #38: Cry Me a River
#   Artists: Jack and White, Brooke White
#   Album: Undercover
#   Track URI: spotify:track:4j0IcOchPkhypzZeDWmTOj
#
# #39: 21:13
#   Artists: Coheed and Cambria
#   Album: In Keeping Secrets Of Silent Earth: 3
#   Track URI: spotify:track:0MFEW9QSrRgtdrqINJavJB
#
# #40: No Where
#   Artists: Stars and Stripes
#   Album: Shaved For Battle
#   Track URI: spotify:track:70uwAaMxHar731WIUNY8zu
#
# #41: The Guns (feat. Guilty Simpson, MED & Pok Dog)
#   Artists: Oh No, Guilty Simpson, MED, Pok Dog
#   Album: Ohnomite
#   Track URI: spotify:track:0bMkn6redGNsTxggzrT7XE
#
# #42: Blackboard
#   Artists: Mission Of Burma
#   Album: Peking Spring
#   Track URI: spotify:track:6ERQCuFIYaBEEu2AHr4qsV
#
# #43: Skinheads On The Rampage
#   Artists: Stars and Stripes
#   Album: Shaved For Battle
#   Track URI: spotify:track:0flAKSmnhgwFRynudxqjHM
#
# #44: Don't Stop Me Now
#   Artists: The Protomen
#   Album: Present: A Night of Queen
#   Track URI: spotify:track:0fwKtXN5HQkRPGt5yJ2laG
#
# #45: Full Tank
#   Artists: Ben Tankard
#   Album: Full Tank
#   Track URI: spotify:track:4TJAGECCUhbhnzjDlz4Do9
#
# #46: The Ripper
#   Artists: Lita Ford
#   Album: Stiletto
#   Track URI: spotify:track:6WC0m1HDLyOHCXxhKlpDf2
#
# #47: Telephone Line (feat. Fitz)
#   Artists: Jack and White, Brooke White, Fitz
#   Album: Undercover
#   Track URI: spotify:track:0TzCjbF2YbCuoRpqgjT0d7
#
# #48: The Have Nots
#   Artists: Danielle Ate The Sandwich
#   Album: Like a King
#   Track URI: spotify:track:5tnrcZcaYVq3fX7GyVGFdg
#
# #49: Altering the Future
#   Artists: Death
#   Album: Spiritual Healing
#   Track URI: spotify:track:39vBNPpuGv5U6MlNMa346j
#
# #50: Rory Lowery, Private Eye
#   Artists: Brian Bromberg
#   Album: Compared to That
#   Track URI: spotify:track:47hu9bwlcN7gHghbHcUDmZ
