# %%
from typing import Tuple
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score

from adv_ml_music_recommendation.recommenders.collaborativerecommender import CollaborativeRecommender
from adv_ml_music_recommendation.recommenders.contentbasedrecommender import ContentRecommender
from adv_ml_music_recommendation.recommenders.hybridrecommender import HybridRecommender
from adv_ml_music_recommendation.recommenders.popularityrecommender import PopularityRecommender
from adv_ml_music_recommendation.util.data_functions import get_interacted_tracks
from adv_ml_music_recommendation.recommenders.abstractrecommender import AbstractSongRecommender
from adv_ml_music_recommendation.util.data_functions import get_number_of_songs_in_playlist

class RecommenderEvaluator:
    def __init__(self, df_playlist: pd.DataFrame, df_tracks: pd.DataFrame, type: str = 'collaborative'):
        self.df_train_playlist = []
        self.df_test_playlist = []
        self.df_tracks = df_tracks

        # Filter out playlists with fewer than 10 songs
        filtered_playlists = [pid for pid in df_playlist['playlist_id'] if get_number_of_songs_in_playlist(df_playlist, pid) >= 10]

        # Renumber the filtered playlist_ids to remove gaps
        df_playlist = list(range(1, len(filtered_playlists) + 1))

        # Group by playlist_id and perform train-test split for each playlist
        for playlist_id, group in df_playlist.groupby('playlist_id'):
            if playlist_id > 1000:
                break

            if playlist_id % 100 == 0:
                print(playlist_id)

            # Extract track_uris for the current playlist
            track_uris = group['track_uri'].tolist()

            # Perform train-test split
            train_uris, test_uris = train_test_split(track_uris, test_size=0.2, random_state=42)

            # Append the results to the train and test lists
            for uri in train_uris:
                 self.df_train_playlist.append({'playlist_id': playlist_id, 'track_uri': uri})

            for uri in test_uris:
                 self.df_test_playlist.append({'playlist_id': playlist_id, 'track_uri': uri})


        self.df_train_playlist = pd.DataFrame(self.df_train_playlist)
        self.df_test_playlist = pd.DataFrame(self.df_test_playlist)

        # Filter the tracks dataframe to keep only tracks that appear in the playlists dataframe:
        # & operator feels like questionable design
        print(self.df_train_playlist)
        #self.df_tracks = self.df_tracks[self.df_tracks['track_uri'].isin(self.df_train_data['track_uri']) & self.df_tracks['track_uri'].isin(self.df_test_data['track_uri'])]
        self.df_tracks = self.df_tracks[self.df_tracks['track_uri'].isin(self.df_train_playlist['track_uri'])]

        if type == 'hybrid':
            self.train_data_model = HybridRecommender(df_playlist=self.df_train_playlist, df_tracks=self.df_tracks)
            self.test_data_model = HybridRecommender(df_playlist=self.df_test_playlist, df_tracks=self.df_tracks)
        elif type == 'collaborative':
            self.train_data_model = CollaborativeRecommender(df_playlist=self.df_train_playlist, df_tracks=self.df_tracks)
            self.test_data_model = CollaborativeRecommender(df_playlist=self.df_test_playlist, df_tracks=self.df_tracks)
        elif type == 'content':
            self.train_data_model = ContentRecommender(df_playlist=self.df_train_playlist, df_tracks=self.df_tracks)
            self.test_data_model = ContentRecommender(df_playlist=self.df_test_playlist, df_tracks=self.df_tracks)
        elif type == 'popularity':
            self.train_data_model = PopularityRecommender(df_playlist=self.df_train_playlist, df_tracks=self.df_tracks)
            self.test_data_model = PopularityRecommender(df_playlist=self.df_test_playlist, df_tracks=self.df_tracks)
        else:
            raise ValueError(
                f"Invalid type: {type}. Must be one of 'hybrid', 'collaborative', 'content', 'popularity'.")


    def evaluate_recommender_for_playlist(self, playlist_id):
        # Get recommendations from the train model
        ranked_recommendations_df = self.train_data_model.recommend_tracks(playlist_id)

        # Extract the recommended track URIs
        recommended_track_uris = ranked_recommendations_df['track_uri'].tolist()

        # Get the ground truth: test track URIs for the playlist
        test_track_uris = self.df_test_playlist[self.df_test_playlist['playlist_id'] == playlist_id]['track_uri'].iloc[0]

        # Create binary vectors for precision and recall calculation
        y_true = [1 if uri in test_track_uris else 0 for uri in recommended_track_uris]
        y_pred = [1] * len(recommended_track_uris)  # All recommendations are predicted as relevant

        # Compute precision and recall
        precision = precision_score(y_true, y_pred, zero_division=0)
        recall = recall_score(y_true, y_pred, zero_division=0)

        return precision, recall


    def evaluate_model(self):
        total_precision = 0
        total_recall = 0
        num_playlists = len(self.df_test_playlist)

        # Iterate over all playlists in the test_data
        for playlist_id in self.df_test_playlist['playlist_id'].unique():
            precision, recall = self.evaluate_recommender_for_playlist(playlist_id)
            total_precision += precision
            total_recall += recall

        # Compute average precision and recall
        avg_precision = total_precision / num_playlists
        avg_recall = total_recall / num_playlists

        return {
            'average_precision': avg_precision,
            'average_recall': avg_recall
        }

# %%
df_playlist = pd.read_csv("../../../data/track_playlist_association.csv")
df_tracks = pd.read_csv("../../../data/matched_songs.csv")
print(df_tracks)
# Out:
#         Unnamed: 0  pos        artist_name  \
# 0                0    1     Britney Spears
# 1                0    3  Justin Timberlake
# 2                0    8    Destiny's Child
# 3                0    9            OutKast
# 4                0   19    Destiny's Child
# ...            ...  ...                ...
# 134707         829   24        The Outlaws
# 134708         829  131        The Outlaws
# 134709         870   69    History Invades
# 134710         887    5          Limi-T 21
# 134711         935   32        Rod Stewart
#
#                                    track_uri  \
# 0       spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 1       spotify:track:1AWQoqb9bSvzTjaLralEkT
# 2       spotify:track:7H6ev70Weq6DdpZyyTmUXk
# 3       spotify:track:2PpruBYCo4H7WOBJ7Q2EwM
# 4       spotify:track:4pmc2AxSEq6g7hPVlJCPyP
# ...                                      ...
# 134707  spotify:track:38Zq6XbsyIcwI0Kn1ikPlV
# 134708  spotify:track:68nYzKdsOUiiVAuyAc5y3U
# 134709  spotify:track:2U7FCJK3m012zjvPlAw4PK
# 134710  spotify:track:1HkPxeUaQwIFIbYCRq9nyK
# 134711  spotify:track:533lw7eUjXE5ZbajU8L4H6
#
#                                    artist_uri  \
# 0       spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 1       spotify:artist:31TPClRtHm23RisEBtV3X7
# 2       spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i
# 3       spotify:artist:1G9G7WwrXka3Z1r7aIDjI7
# 4       spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i
# ...                                       ...
# 134707  spotify:artist:72JEwd3EjDEwTLypkFYJn9
# 134708  spotify:artist:72JEwd3EjDEwTLypkFYJn9
# 134709  spotify:artist:0uDgv6be8MjRPqZ1v7WiZa
# 134710  spotify:artist:5j8Q0VC4Be4yhcQ1tf8Sh7
# 134711  spotify:artist:2y8Jo9CKhJvtfeKOsYzRdT
#
#                                                track_name  \
# 0                                                   Toxic
# 1                                          Rock Your Body
# 2                                             Say My Name
# 3                          Hey Ya! - Radio Mix / Club Mix
# 4                                        Jumpin', Jumpin'
# ...                                                   ...
# 134707                                       Freedom Walk
# 134708                                         Dirty City
# 134709                              Its All Over (Ending)
# 134710                   Una Despedida (Tropical version)
# 134711  Standin' In the Shadows of Love - 2008 Remaste...
#
#                                    album_uri  duration_ms_x  \
# 0       spotify:album:0z7pVBGOD7HCIB7S8eLkLI         198800
# 1       spotify:album:6QPkyl04rXwTGlGlcYaRoW         267266
# 2       spotify:album:283NWqNsCA9GwVHrJk59CG         271333
# 3       spotify:album:1UsmQ3bpJTyK6ygoOOjG1r         235213
# 4       spotify:album:283NWqNsCA9GwVHrJk59CG         230200
# ...                                      ...            ...
# 134707  spotify:album:7IHvSlqB21xW52rQcLez8a         346880
# 134708  spotify:album:7Lu3iMeH7KWrbqnXHfgEgU         327426
# 134709  spotify:album:4774uhbJcNqmK2PDpTKC92         141626
# 134710  spotify:album:3D2qTNwjpvoK1d4t53BjaT         219066
# 134711  spotify:album:38tXOrjXUUfQWWV2DRwMio         268266
#
#                                 album_name                      id  ...  \
# 0                              In The Zone  6I9VzXrHxO9rA9A5euc8Ak  ...
# 1                                Justified  1AWQoqb9bSvzTjaLralEkT  ...
# 2                The Writing's On The Wall  7H6ev70Weq6DdpZyyTmUXk  ...
# 3              Speakerboxxx/The Love Below  2PpruBYCo4H7WOBJ7Q2EwM  ...
# 4                The Writing's On The Wall  4pmc2AxSEq6g7hPVlJCPyP  ...
# ...                                    ...                     ...  ...
# 134707                        Ghost Riders  38Zq6XbsyIcwI0Kn1ikPlV  ...
# 134708                      Playin' to Win  68nYzKdsOUiiVAuyAc5y3U  ...
# 134709  The Structure Of A Precise Fashion  2U7FCJK3m012zjvPlAw4PK  ...
# 134710                            Adictivo  1HkPxeUaQwIFIbYCRq9nyK  ...
# 134711               Blondes Have More Fun  533lw7eUjXE5ZbajU8L4H6  ...
#
#        speechiness acousticness instrumentalness liveness valence    tempo  \
# 0           0.1140      0.02490         0.025000   0.2420   0.924  143.040
# 1           0.1400      0.20200         0.000234   0.0521   0.818  100.972
# 2           0.1020      0.27300         0.000000   0.1490   0.734  138.009
# 3           0.0664      0.10300         0.000532   0.1740   0.965   79.526
# 4           0.0567      0.00543         0.001570   0.0537   0.683   88.997
# ...            ...          ...              ...      ...     ...      ...
# 134707      0.0605      0.06140         0.013900   0.1550   0.693   90.245
# 134708      0.0454      0.00854         0.000313   0.5000   0.884  127.566
# 134709      0.0562      0.00431         0.117000   0.2740   0.192  160.262
# 134710      0.0374      0.27400         0.000141   0.1470   0.926  124.949
# 134711      0.0361      0.02500         0.000483   0.1100   0.825  116.080
#
#         duration_ms_y  time_signature  year  release_date
# 0              198800             4.0  2003    2003-11-13
# 1              267267             4.0  2002    2002-11-04
# 2              271333             4.0  1999    1999-07-27
# 3              235213             4.0  2003          2003
# 4              230200             4.0  1999    1999-07-27
# ...               ...             ...   ...           ...
# 134707         346880             4.0  1980    1980-09-03
# 134708         327427             4.0  1978          1978
# 134709         141627             4.0  2005    2005-07-19
# 134710         219067             4.0  2010    2010-01-01
# 134711         268267             4.0  1978    1978-11-24
#
# [134712 rows x 33 columns]

# %%
# Out:
# 0         spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 1         spotify:track:1AWQoqb9bSvzTjaLralEkT
# 2         spotify:track:7H6ev70Weq6DdpZyyTmUXk
# 3         spotify:track:2PpruBYCo4H7WOBJ7Q2EwM
# 4         spotify:track:4pmc2AxSEq6g7hPVlJCPyP
#                           ...
# 134707    spotify:track:38Zq6XbsyIcwI0Kn1ikPlV
# 134708    spotify:track:68nYzKdsOUiiVAuyAc5y3U
# 134709    spotify:track:2U7FCJK3m012zjvPlAw4PK
# 134710    spotify:track:1HkPxeUaQwIFIbYCRq9nyK
# 134711    spotify:track:533lw7eUjXE5ZbajU8L4H6
# Name: track_uri, Length: 134712, dtype: object

# %%
evaluator = RecommenderEvaluator(df_playlist=df_playlist, df_tracks=df_tracks)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 evaluator = RecommenderEvaluator(df_playlist=df_playlist, df_tracks=df_tracks)
#
# Cell In[137], line 20, in RecommenderEvaluator.__init__(self, df_playlist, df_tracks, type)
#      17 self.df_tracks = df_tracks
#      19 # Filter out playlists with fewer than 10 songs
# ---> 20 filtered_playlists = [pid for pid in df_playlist['playlist_id'] if get_number_of_songs_in_playlist(df_playlist, pid) >= 10]
#      22 # Renumber the filtered playlist_ids to remove gaps
#      23 df_playlist = list(range(1, len(filtered_playlists) + 1))
#
# Cell In[137], line 20, in <listcomp>(.0)
#      17 self.df_tracks = df_tracks
#      19 # Filter out playlists with fewer than 10 songs
# ---> 20 filtered_playlists = [pid for pid in df_playlist['playlist_id'] if get_number_of_songs_in_playlist(df_playlist, pid) >= 10]
#      22 # Renumber the filtered playlist_ids to remove gaps
#      23 df_playlist = list(range(1, len(filtered_playlists) + 1))
#
# File ~/AI/AML/adv-ml-music-recommendation/adv_ml_music_recommendation/util/data_functions.py:87, in get_number_of_songs_in_playlist(df, playlist_id)
#      79 def get_number_of_songs_in_playlist(df: pd.DataFrame, playlist_id: int) -> int:
#      80     """
#      81     Get the number of songs in a specific playlist.
#      82
#    (...)
#      85     :return: The number of songs in the playlist.
#      86     """
# ---> 87     return df[df['playlist_id'] == playlist_id].shape[0]
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:893, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 n = self.shape[axis]
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
# --> 893 new_labels = self.axes[axis].take(indexer)
#     894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#    (...)
#     899     copy=None,
#     900 )
#
# File ~/AI/AML/adv-ml-music-recommendation/.venv/lib/python3.11/site-packages/pandas/core/indexes/range.py:1158, in RangeIndex.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1156 if kwargs:
#    1157     nv.validate_take((), kwargs)
# -> 1158 if is_scalar(indices):
#    1159     raise TypeError("Expected indices to be array-like")
#    1160 indices = ensure_platform_int(indices)
#
# KeyboardInterrupt:

# %%
print(evaluator.df_train_playlist['playlist_id'].unique())
# Out:
# [  0   1   2   3   4   5   7   8   9  10  11  14  16  17  18  19  20  22
#   24  25  28  29  30  31  32  34  35  37  38  39  40  41  42  44  45  49
#   50  51  53  55  56  59  60  63  64  65  66  68  70  71  72  73  80  83
#   85  88  89  90  91  93  94  95  96  97  98 101 102 103 105 106 107 109
#  112 114 115 118 119 120 121 122 123 124 125 126 127 128 129 130 131 133
#  134 135 136 138 139 140 142 143 144 145 146 148 149 150 151 152 153 154
#  155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 172 173
#  176 177 178 179 180 182 183 184 185 186 189 192 194 195 196 197 199 200
#  201 202 203 205 207 208 209 210 211 212 214 215 217 218 219 220 223 224
#  225 227 228 231 232 233 234 236 237 239 240 241 242 243 244 245 246 247
#  248 249 250 252 253 254 255 256 258 259 260 262 263 264 265 267 268 271
#  273 274 275 277 279 280 281 282 283 284 285 290 291 293 294 295 297 298
#  299 302 305 307 309 310 314 315 316 321 323 326 328 329 330 331 332 333
#  334 335 338 339 341 342 343 344 348 349 350 351 354 355 356 357 358 359
#  360 361 362 363 364 365 367 368 369 370 373 374 375 376 378 379 380 382
#  384 386 389 392 393 395 396 397 399 400 401 403 404 405 406 407 411 412
#  413 416 418 419 420 421 422 424 426 427 428 429 430 431 432 434 435 436
#  437 438 439 440 441 442 443 446 447 448 452 453 454 456 457 458 460 462
#  465 469 470 471 472 473 475 476 478 479 480 483 484 485 487 488 491 493
#  494 495 496 497 498 499 500 502 504 505 506 507 508 509 510 511 513 514
#  515 516 520 521 523 524 526 527 528 529 530 532 540 541 542 543 544 545
#  546 549 551 552 553 554 555 556 557 558 559 560 562 563 565 567 568 570
#  572 573 575 577 578 579 580 582 583 584 585 586 588 589 590 592 593 596
#  597 598 600 602 603 604 605 606 607 608 609 610 611 612 613 614 616 617
#  619 620 621 623 625 626 627 628 629 630 632 633 634 635 636 637 642 643
#  644 646 647 648 649 650 651 653 654 655 656 657 658 659 660 661 662 663
#  664 666 669 672 673 674 676 677 679 680 682 683 686 687 688 689 690 691
#  693 694 697 698 699 700 701 702 703 704 705 708 709 712 713 714 715 716
#  717 718 722 724 727 728 729 730 731 733 734 735 737 740 742 743 744 745
#  747 750 751 752 754 755 756 757 758 759 760 761 762 763 764 766 767 768
#  769 770 772 773 775 779 781 782 783 785 786 788 789 790 791 793 795 796
#  797 799 802 803 804 805 806 807 808 810 811 812 813 815 816 817 821 822
#  823 825 827 828 829 831 832 833 835 836 838 839 840 842 843 844 847 848
#  849 852 854 855 856 857 858 859 860 861 862 863 864 865 866 867 869 870
#  871 872 873 874 876 879 880 881 883 884 886 887 888 889 893 894 895 896
#  898 899 900 901 902 903 904 906 907 908 909 910 912 913 914 915 916 917
#  918 919 920 921 923 924 925 926 927 930 932 933 934 935 936 937 938 940
#  941 942 943 944 946 948 949 950 953 954 955 956 959 964 965 968 970 971
#  972 973 974 975 977 978 979 980 982 984 985 986 987 989 990 991 992 993
#  995 997 998 999]

# %%
evaluator.evaluate_model()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 evaluator.evaluate_model()
#
# Cell In[131], line 97, in RecommenderEvaluator.evaluate_model(self)
#      95 # Iterate over all playlists in the test_data
#      96 for playlist_id in self.df_test_playlist['playlist_id'].unique():
# ---> 97     precision, recall = self.evaluate_recommender_for_playlist(playlist_id)
#      98     total_precision += precision
#      99     total_recall += recall
#
# Cell In[131], line 71, in RecommenderEvaluator.evaluate_recommender_for_playlist(self, playlist_id)
#      69 def evaluate_recommender_for_playlist(self, playlist_id):
#      70     # Get recommendations from the train model
# ---> 71     ranked_recommendations_df = self.train_data_model.recommend_tracks(playlist_id)
#      73     # Extract the recommended track URIs
#      74     recommended_track_uris = ranked_recommendations_df['track_uri'].tolist()
#
# File ~/AI/AML/adv-ml-music-recommendation/adv_ml_music_recommendation/recommenders/collaborativerecommender.py:52, in CollaborativeRecommender.recommend_tracks(self, playlist_id, top_k)
#      48 def recommend_tracks(self, playlist_id: int, top_k: int = 10) -> pd.DataFrame:
#      49     """
#      50     Recommends top N tracks for the given playlist based on predicted ratings.
#      51     """
# ---> 52     predicted_ratings = self.get_predicted_ratings_for_playlist(playlist_id)
#      54     # Create a DataFrame of all tracks with their predicted ratings
#      55     recommendations = self.df_tracks.copy()
#
# File ~/AI/AML/adv-ml-music-recommendation/adv_ml_music_recommendation/recommenders/collaborativerecommender.py:35, in CollaborativeRecommender.get_predicted_ratings_for_playlist(self, playlist_id, normalize)
#      33 def get_predicted_ratings_for_playlist(self, playlist_id: int, normalize: bool = True) -> np.ndarray:
#      34     # Multiply the playlist row by the singular values
# ---> 35     playlist_ratings = self.u[playlist_id, :] @ np.diag(self.s)
#      37     # Multiply the result by vt to get the predicted ratings for all tracks for that playlist
#      38     predicted_ratings = playlist_ratings @ self.vt
#
# IndexError: index 708 is out of bounds for axis 0 with size 706
